-- %%
print [ (x,y,x+y) | x<-[1,2,3], y<-[4,5,6], x*y>7 ]
-- Out:
-- [(2,4,6),(2,5,7),(2,6,8),(3,4,7),(3,5,8),(3,6,9)]

-- %% [markdown]
-- 2016_08_25_-_Martin_Ockajak_-_Comparing_Haskell_and_Scala-5OBNUzbMtZE.mp4

-- %%
do print "ala"
-- Out:
-- Line 1: Redundant do
-- Found:
-- do print "ala"
-- Why not:
-- print "ala"
-- "ala"

-- %%
import Yesod

-- %%
{-# LANGUAGE OverloadedStrings     #-}
{-# LANGUAGE QuasiQuotes           #-}
{-# LANGUAGE TemplateHaskell       #-}
{-# LANGUAGE TypeFamilies          #-}
import           Yesod

data HelloWorld = HelloWorld

mkYesod "HelloWorld" [parseRoutes|
/ HomeR GET
/page1 Page1R GET
/page2 Page2R GET
|]

instance Yesod HelloWorld

getHomeR :: Handler Html
getHomeR = defaultLayout [whamlet|Hello <b>World!</b>|]

getPage1R = defaultLayout [whamlet|<a href=@{Page2R}>Go to page 2!|]
getPage2R = defaultLayout [whamlet|<a href=@{HomeR}>Go home!|]

main :: IO ()
main = warp 3000 HelloWorld
-- Out:
-- Parse error (line 9, column 35): unterminated quasiquotation at end of input
-- Parse error (line 10, column 1): parse error on input ‘/’
-- Parse error (line 11, column 1): parse error on input ‘/’
-- Parse error (line 12, column 1): parse error on input ‘/’
-- Parse error (line 20, column 1): parse error on input ‘instance’
-- Parse error (line 21, column 11): parse error on input ‘=’
-- Perhaps you need a 'let' in a 'do' block?
-- e.g. 'let x = 5' instead of 'x = 5'

-- %%
{-# LANGUAGE FlexibleContexts, DatatypeContexts #-}

import Control.Monad.Error

data Show a =>
    DivByError a = DivBy0
                  | ForbiddenDenominator a
                  | OtherDivByError String
                    deriving (Eq, Read, Show)

instance Error (DivByError a) where
    strMsg x = OtherDivByError x

divBy :: Integral a => a -> [a] -> Either (DivByError a) [a]
divBy = divByGeneric

divByGeneric :: (Integral a, MonadError (DivByError a) m) =>
                 a -> [a] -> m [a]
divByGeneric _ [] = return []
divByGeneric _ (0:_) = throwError DivBy0
divByGeneric _ (10:_) = throwError (ForbiddenDenominator 10)
divByGeneric _ (20:_) = throwError (ForbiddenDenominator 20)
divByGeneric numerator (denom:xs) =
    do next <- divByGeneric numerator xs
       return ((numerator `div` denom) : next)
-- Out:
-- Warning: -XDatatypeContexts is deprecated: It was widely considered a misfeature, and has been removed from the Haskell language.
-- <interactive>:14:37: error:
--     • Could not deduce (Show a) arising from a use of ‘ForbiddenDenominator’
--       from the context: (Integral a, MonadError (DivByError a) m)
--         bound by the type signature for:
--                    divByGeneric :: (Integral a, MonadError (DivByError a) m) => a -> [a] -> m [a]
--         at <interactive>:(10,1)-(11,34)
--       Possible fix:
--         add (Show a) to the context of
--           the type signature for:
--             divByGeneric :: (Integral a, MonadError (DivByError a) m) => a -> [a] -> m [a]
--     • In the first argument of ‘throwError’, namely ‘(ForbiddenDenominator 10)’
--       In the expression: throwError (ForbiddenDenominator 10)
--       In an equation for ‘divByGeneric’: divByGeneric _ (10 : _) = throwError (ForbiddenDenominator 10)

-- %%
print $ fmap (+1) [2, 7, 9]
-- Out:
-- [3,8,10]

-- %%
print $ show [Just 123, Nothing]
-- Out:
-- "[Just 123,Nothing]"
